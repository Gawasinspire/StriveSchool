# %%
# Decision Tree example from sci kit learn

from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
from pprint import pprint
import sys
import seaborn as sns
import matplotlib.pyplot as plt

# %%
X = [[0, 0], [1, 1]]
Y = [0, 1]
clf = tree.DecisionTreeClassifier() 
clf = clf.fit(X, Y)

# %%
print(clf.predict([[2., 2.]]))   # 2,2 belongs to 1
tree.plot_tree(clf)
# Out:
# [1]
# [Text(167.4, 163.07999999999998, 'X[0] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(83.7, 54.360000000000014, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(251.10000000000002, 54.360000000000014, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
iris = load_iris()
X, y = iris.data, iris.target
clf = tree.DecisionTreeClassifier(max_depth = 2)
clf = clf.fit(X, y)

# %%
len(X)
# Out:
# 101

# %%
tree.plot_tree(clf)
# Out:
# [Text(133.92000000000002, 181.2, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(66.96000000000001, 108.72, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(200.88000000000002, 108.72, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(133.92000000000002, 36.23999999999998, 'gini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(267.84000000000003, 36.23999999999998, 'gini = 0.043\nsamples = 46\nvalue = [0, 1, 45]')]

# %%
clf = DecisionTreeClassifier(random_state=0)
iris = load_iris()
cross_val_score(clf, iris.data, iris.target, cv=10)

# %%
#df = pd.read_csv("zoo.names")
#df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-27-cce848e17387> in <module>
# ----> 1 df = pd.read_csv("zoo.names")
#       2 df
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1194     def read(self, nrows=None):
#    1195         nrows = _validate_integer("nrows", nrows)
# -> 1196         ret = self._engine.read(nrows)
#    1197
#    1198         # May alter columns / col_dict
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2153     def read(self, nrows=None):
#    2154         try:
# -> 2155             data = self._reader.read(nrows)
#    2156         except StopIteration:
#    2157             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 23, saw 7

# %%
# read zoo.data
header_list = ["animal_name",
               "hair",
               "feathers",
               "eggs",
               "milk",
               "airborne",
               "aquatic",
               "predator",
               "toothed",
               "breathes",
               "backbone",
               "venomous",
               "fins",
               "legs",
               "tail",
               "domestic",
               "catsize",
               "type"
              ]
df = pd.read_csv("zoo.data", names=header_list)

# split based on ,

# add 18 column
# Out:
#              hair    feathers        eggs        milk    airborne     aquatic  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.425743    0.198020    0.584158    0.405941    0.237624    0.356436
# std      0.496921    0.400495    0.495325    0.493522    0.427750    0.481335
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    0.000000    1.000000    1.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          predator     toothed    breathes    backbone    venomous        fins  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.554455    0.603960    0.821782    0.792079    0.079208    0.168317
# std      0.499505    0.491512    0.384605    0.407844    0.271410    0.376013
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000    1.000000    0.000000    0.000000
# 50%      1.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#              legs        tail    domestic     catsize        type
# count  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     2.841584    0.742574    0.128713    0.435644    2.831683
# std      2.033385    0.439397    0.336552    0.498314    2.102709
# min      0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      2.000000    0.000000    0.000000    0.000000    1.000000
# 50%      4.000000    1.000000    0.000000    0.000000    2.000000
# 75%      4.000000    1.000000    0.000000    1.000000    4.000000
# max      8.000000    1.000000    1.000000    1.000000    7.000000

# %%
df
# Out:
#     animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark     1         0     0     1         0        0         1
# 1      antelope     1         0     0     1         0        0         0
# 2          bass     0         0     1     0         0        1         1
# 3          bear     1         0     0     1         0        0         1
# 4          boar     1         0     0     1         0        0         1
# ..          ...   ...       ...   ...   ...       ...      ...       ...
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
#      toothed  breathes  backbone  venomous  fins  legs  tail  domestic  \
# 0          1         1         1         0     0     4     0         0
# 1          1         1         1         0     0     4     1         0
# 2          1         1         0         0     1     0     1         0
# 3          1         1         1         0     0     4     0         0
# 4          1         1         1         0     0     4     1         0
# ..       ...       ...       ...       ...   ...   ...   ...       ...
# 96         1         1         1         0     0     2     1         0
# 97         0         0         1         1     0     6     0         0
# 98         1         1         1         0     0     4     1         0
# 99         0         0         1         0     0     0     0         0
# 100        0         1         1         0     0     2     1         0
#
#      catsize  type
# 0          1     1
# 1          1     1
# 2          0     4
# 3          1     1
# 4          1     1
# ..       ...   ...
# 96         1     1
# 97         0     6
# 98         1     1
# 99         0     7
# 100        0     2
#
# [101 rows x 18 columns]

# %%
y = np.array(df['type'])
X = np.array(df.drop(columns=['animal_name', 'type']))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

#X_test_norm = StandardScaler().fit_transform(X_test)
#X_train_norm = StandardScaler().fit_transform(X_train)

# %%
criterion = ['gini', 'entropy']

for i in criterion:
    accuracy = []
    for j in range(1,10):
        clf = DecisionTreeClassifier(random_state=0, criterion=i, max_depth=j)
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        depth = clf.get_depth()
        accuracy.append(accuracy_score(y_pred, y_test))
        print(f'Selected criterion is {i}, selected max_depth is: {j}')
        print('The depth of the decision tree is: ', clf.get_depth())
        #print(confusion_matrix(y_test, y_hat))
        print(f'The accuracy of the model with max depth = {depth} is: {accuracy_score(y_pred, y_test)} \n')
    sns.lineplot(range(1, 10), accuracy,color='blue')
    plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})
    plt.title(f'accuracy of {i}')
    plt.show()
# Out:
# Selected criterion is gini, selected max_depth is: 1
# The depth of the decision tree is:  1
# The accuracy of the model with max depth = 1 is: 0.5714285714285714
#
# Selected criterion is gini, selected max_depth is: 2
# The depth of the decision tree is:  2
# The accuracy of the model with max depth = 2 is: 0.7142857142857143
#
# Selected criterion is gini, selected max_depth is: 3
# The depth of the decision tree is:  3
# The accuracy of the model with max depth = 3 is: 0.7619047619047619
#
# Selected criterion is gini, selected max_depth is: 4
# The depth of the decision tree is:  4
# The accuracy of the model with max depth = 4 is: 0.7619047619047619
#
# Selected criterion is gini, selected max_depth is: 5
# The depth of the decision tree is:  5
# The accuracy of the model with max depth = 5 is: 0.8095238095238095
#
# Selected criterion is gini, selected max_depth is: 6
# The depth of the decision tree is:  6
# The accuracy of the model with max depth = 6 is: 0.9047619047619048
#
# Selected criterion is gini, selected max_depth is: 7
# The depth of the decision tree is:  6
# The accuracy of the model with max depth = 6 is: 0.9047619047619048
#
# Selected criterion is gini, selected max_depth is: 8
# The depth of the decision tree is:  6
# The accuracy of the model with max depth = 6 is: 0.9047619047619048
#
# Selected criterion is gini, selected max_depth is: 9
# The depth of the decision tree is:  6
# The accuracy of the model with max depth = 6 is: 0.9047619047619048
# /home/simple/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Selected criterion is entropy, selected max_depth is: 1
# The depth of the decision tree is:  1
# The accuracy of the model with max depth = 1 is: 0.5714285714285714
#
# Selected criterion is entropy, selected max_depth is: 2
# The depth of the decision tree is:  2
# The accuracy of the model with max depth = 2 is: 0.7142857142857143
#
# Selected criterion is entropy, selected max_depth is: 3
# The depth of the decision tree is:  3
# The accuracy of the model with max depth = 3 is: 0.7619047619047619
#
# Selected criterion is entropy, selected max_depth is: 4
# The depth of the decision tree is:  4
# The accuracy of the model with max depth = 4 is: 0.8095238095238095
#
# Selected criterion is entropy, selected max_depth is: 5
# The depth of the decision tree is:  5
# The accuracy of the model with max depth = 5 is: 0.9047619047619048
#
# Selected criterion is entropy, selected max_depth is: 6
# The depth of the decision tree is:  5
# The accuracy of the model with max depth = 5 is: 0.9047619047619048
#
# Selected criterion is entropy, selected max_depth is: 7
# The depth of the decision tree is:  5
# The accuracy of the model with max depth = 5 is: 0.9047619047619048
#
# Selected criterion is entropy, selected max_depth is: 8
# The depth of the decision tree is:  5
# The accuracy of the model with max depth = 5 is: 0.9047619047619048
#
# Selected criterion is entropy, selected max_depth is: 9
# The depth of the decision tree is:  5
# The accuracy of the model with max depth = 5 is: 0.9047619047619048
# /home/simple/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
y = np.array(df['type'])
X = np.array(df.drop(columns=['animal_name', 'type']))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = 6)  

plt.figure()
clf = clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
tree.plot_tree(clf)
# Out:
# [Text(421.94444444444446, 350.5357142857143, 'X[3] <= 0.5\nentropy = 2.333\nsamples = 80\nvalue = [35, 16, 5, 8, 4, 4, 8]'),
#  Text(361.6666666666667, 296.6071428571429, 'X[1] <= 0.5\nentropy = 2.389\nsamples = 45\nvalue = [0, 16, 5, 8, 4, 4, 8]'),
#  Text(301.3888888888889, 242.67857142857142, 'X[8] <= 0.5\nentropy = 2.251\nsamples = 29\nvalue = [0, 0, 5, 8, 4, 4, 8]'),
#  Text(180.83333333333334, 188.75, 'X[6] <= 0.5\nentropy = 0.918\nsamples = 12\nvalue = [0, 0, 0, 0, 0, 4, 8]'),
#  Text(120.55555555555556, 134.82142857142856, 'X[12] <= 3.0\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 4, 1]'),
#  Text(60.27777777777778, 80.89285714285711, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(180.83333333333334, 80.89285714285711, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 0, 4, 0]'),
#  Text(241.11111111111111, 134.82142857142856, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 0, 0, 7]'),
#  Text(421.94444444444446, 188.75, 'X[11] <= 0.5\nentropy = 1.522\nsamples = 17\nvalue = [0, 0, 5, 8, 4, 0, 0]'),
#  Text(361.6666666666667, 134.82142857142856, 'X[5] <= 0.5\nentropy = 0.991\nsamples = 9\nvalue = [0, 0, 5, 0, 4, 0, 0]'),
#  Text(301.3888888888889, 80.89285714285711, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0, 0]'),
#  Text(421.94444444444446, 80.89285714285711, 'X[12] <= 2.0\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 1, 0, 4, 0, 0]'),
#  Text(361.6666666666667, 26.964285714285722, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]'),
#  Text(482.22222222222223, 26.964285714285722, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0, 0]'),
#  Text(482.22222222222223, 134.82142857142856, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0, 0]'),
#  Text(421.94444444444446, 242.67857142857142, 'entropy = 0.0\nsamples = 16\nvalue = [0, 16, 0, 0, 0, 0, 0]'),
#  Text(482.22222222222223, 296.6071428571429, 'entropy = 0.0\nsamples = 35\nvalue = [35, 0, 0, 0, 0, 0, 0]')]
